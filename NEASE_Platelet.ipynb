# %%
import  NEASE
import pandas as pd
# Out:
# /home/zakaria/anaconda3/envs/z1/lib/python3.5/site-packages/IPython/core/interactiveshell.py:3249: DtypeWarning:
#
# Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
# Platelet dataset 
table= pd.read_table("/home/zakaria/projects/exon_enrch/data/platelets_ds/MAJIQ/healthy-mp_healthy-rp_deltapsi/RP_MP.deltapsi.tsv")

# %%
table
# Out:
#                     Gene ID                                      LSV ID  \
# 0      gene:ENSG00000114541    gene:ENSG00000114541:s:69216263-69216349
# 1      gene:ENSG00000013016    gene:ENSG00000013016:t:31249371-31249468
# 2      gene:ENSG00000163249  gene:ENSG00000163249:t:207737411-207737446
# 3      gene:ENSG00000175768    gene:ENSG00000175768:s:37592253-37592604
# 4      gene:ENSG00000171314    gene:ENSG00000171314:s:97426191-97426446
# ...                     ...                                         ...
# 12803  gene:ENSG00000188529    gene:ENSG00000188529:s:23971573-23971626
# 12804  gene:ENSG00000182628    gene:ENSG00000182628:s:59131281-59131367
# 12805  gene:ENSG00000236790      gene:ENSG00000236790:s:8240447-8243641
# 12806  gene:ENSG00000125952    gene:ENSG00000125952:t:65075124-65076663
# 12807  gene:ENSG00000129353    gene:ENSG00000129353:t:10626253-10626301
#
#                                                                 LSV Type  \
# ...

# %%
events=NEASE.run(table, organism='Human',input_type='MAJIQ')
# Out:
# Processing MAJIQ format...
# MAJIQ output converted successfully to NEASE format.
#
# 		Data Summary
# **************************************************
# 25 protein domains are affected by AS.
# 17 of the affected domains have known interactions.
# 184 protein interactions/binding affected.
#
# **************************************************
# Running enrichment analysis...
# NEASE enrichment done.

# %%
events.get_domains().head(35)
# Out:
#    Gene name NCBI gene ID   Gene stable ID   Exon stable ID  Pfam ID  \
# 0      PPM1A         5494  ENSG00000100614  ENSE00003598557  PF00481
# 1      SCFD2       152579  ENSG00000184178  ENSE00001327240  PF00995
# 2     PTPN12         5782  ENSG00000127947  ENSE00003466075  PF00102
# 3     ERLEC1        27248  ENSG00000068912  ENSE00000752711  PF07915
# 4       GNAQ         2776  ENSG00000156052  ENSE00001274239  PF00503
# 5   DYNC1LI1        51143  ENSG00000144635  ENSE00003565423  PF05783
# 6      MYOM1         8736  ENSG00000101605  ENSE00001240567  PF00041
# 7       GRK3          157  ENSG00000100077  ENSE00003677641  PF00615
# 8     UBE2V2         7336  ENSG00000169139  ENSE00003509614  PF00179
# 9       CBR4        84869  ENSG00000145439  ENSE00002050409  PF00106
# 10      CBR4        84869  ENSG00000145439  ENSE00003850805  PF13561
# 11    SLAIN2        57606  ENSG00000109171  ENSE00000714290  PF15301
# 12     TCEA1         6917  ENSG00000187735  ENSE00001426483  PF08711
# ...

# %%
events.get_edges()
# Out:
#    Gene name NCBI gene ID      dPSI  Pfam ID  Number of affected interactions  \
# 0       GNAQ         2776  0.457661  PF00503                               34
# 1     UBE2V2         7336  0.427618  PF00179                               33
# 2     PTPN12         5782  0.539035  PF00102                               28
# 3      PRKCA         5578  0.370855  PF00130                               23
# 4      RAB6A         5870  0.267053  PF00071                               22
# 5      PPM1A         5494  0.577477  PF00481                               15
# 6       ARF4          378  0.320421  PF00025                               10
# 7       GRK3          157  0.434388  PF00615                                4
# 8      SCFD2       152579  0.545700  PF00995                                3
# 9   ARHGEF12        23365  0.409407  PF17820                                3
# 10  DYNC1LI1        51143  0.457264  PF05783                                3
# ...

# %%
events.enrich(database=['Reactome']).head(50)
# Out:
# NEASE enrichment for the pathway databases:
#  ['Reactome']
# Found 92 enriched pathways after multiple testing correction.
#        Pathway ID  \
# 0    R-HSA-388396
# 1    R-HSA-372790
# 2    R-HSA-418594
# 3    R-HSA-500792
# 4    R-HSA-416476
# 5    R-HSA-418555
# 6    R-HSA-162582
# 7    R-HSA-418597
# 8   R-HSA-6811442
# 9    R-HSA-373080
# 10   R-HSA-416482
# 11  R-HSA-8873719
# 12   R-HSA-418217
# 13   R-HSA-500657
# 14   R-HSA-392851
# 15   R-HSA-420092
# 16   R-HSA-111885
# 17  R-HSA-8856688
# 18   R-HSA-451326
# 19   R-HSA-199991
# 20  R-HSA-9007101
# 21   R-HSA-373076
# 22  R-HSA-5653656
# 23   R-HSA-422356
# 24  R-HSA-6811436
# 25  R-HSA-2142753
# 26   R-HSA-428930
# 27   R-HSA-112314
# 28  R-HSA-4086398
# 29   R-HSA-397795
# 30   R-HSA-392518
# 31   R-HSA-112043
# 32   R-HSA-112040
# 33   R-HSA-163359
# 34   R-HSA-418592
# 35   R-HSA-163685
# 36   R-HSA-432040
# 37   R-HSA-445717
# 38   R-HSA-418346
# 39  R-HSA-8876198
# 40   R-HSA-112315
# 41   R-HSA-400042
# ...

# %%
events.path_analysis('R-HSA-388396')
# Out:
# Enrichment of the pathway: GPCR downstream signalling.
#
# Overall p_value:  4.9546975801464024e-23
#   Spliced genes NCBI gene ID  Gene knwon to be in the pathway  \
# 0          GNAQ         2776                             True
# 1         PRKCA         5578                             True
# 2          GRK3          157                             True
# 3        PTPN12         5782                            False
# 4          ARF4          378                            False
# 5         RAB6A         5870                            False
# 6      ARHGEF12        23365                             True
# 7         PPM1A         5494                            False
#
#   Percentage of edges associated to the pathway       p_value  \
# 0                                         28/34  5.392154e-29
# 1                                          9/23  3.766092e-06
# 2                                           4/4  1.292340e-05
# ...

# %%
events.path_analysis('R-HSA-418594')
# Out:
# Enrichment of the pathway: G alpha (i) signalling events.
#
# Overall p_value:  5.068891932441552e-14
#   Spliced genes NCBI gene ID  Gene knwon to be in the pathway  \
# 0          GNAQ         2776                            False
# 1          GRK3          157                            False
# 2         PRKCA         5578                             True
# 3         PPM1A         5494                            False
# 4        PTPN12         5782                            False
#
#   Percentage of edges associated to the pathway       p_value  \
# 0                                         18/34  1.611200e-21
# 1                                           3/4  3.983853e-05
# 2                                          3/23  1.297532e-02
# 3                                          1/15  2.797948e-01
# 4                                          1/28  4.581219e-01
#
#                                                                           Affected binding (edges)  \
# ...

# %%
events.Vis_path('R-HSA-418594',k=1)

# %%
events.Vis_path('R-HSA-388396',k=1)

# %%
events.path_analysis('R-HSA-76002')
# Out:
# Enrichment of the pathway: Platelet activation, signaling and aggregation.
#
# Overall p_value:  0.00011939757643627616
#   Spliced genes NCBI gene ID  Gene knwon to be in the pathway  \
# 0          GNAQ         2776                             True
# 1         PRKCA         5578                             True
# 2        PTPN12         5782                            False
# 3         PPM1A         5494                            False
#
#   Percentage of edges associated to the pathway   p_value  \
# 0                                          8/34  0.000199
# 1                                          6/23  0.000698
# 2                                          6/28  0.002109
# 3                                          2/15  0.167167
#
#                    Affected binding (edges)  \
# 0  GNB3,GNB4,F2R,GNG3,GNG4,GNB2,TBXA2R,GNB1
# 1     PRKCB,PLA2G4A,PLCG2,PRKCA,PRKCH,PRKCG
# 2           PTPN6,CSK,GRB2,SHC1,MAPK1,BCAR1
# 3                                PRKCA,AKT1
#
# ...

# %%
events.Vis_path('R-HSA-76002',k=1.5)
